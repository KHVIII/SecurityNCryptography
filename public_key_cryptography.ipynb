# %%
# !pip install pycrypto
# Out:
# ...
#      |████████████████████████████████| 446 kB 6.8 MB/s
# ...
#   Created wheel for pycrypto: filename=pycrypto-2.6.1-cp37-cp37m-linux_x86_64.whl size=499932 sha256=0ec96dd8cb970de49623a817751cd2c9456c302413565a375819bbd3637bdbea
#   Stored in directory: /root/.cache/pip/wheels/cf/85/ba/bbd7c96add459de7598fb424e5ff2309baf2095c844ac0f191
# Successfully built pycrypto
# ...

# %% [markdown]
# # RSA

# %%
from Crypto.Util import *
secret = number.inverse(209,991)
secret
# Out:
# 569

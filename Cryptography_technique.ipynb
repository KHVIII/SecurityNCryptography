# %%
# !pip install PyCryptodome
# !pip install pwntools
# Out:
# Requirement already satisfied: PyCryptodome in /usr/local/lib/python3.7/dist-packages (3.11.0)
# Requirement already satisfied: pwntools in /usr/local/lib/python3.7/dist-packages (4.6.0)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.7/dist-packages (from pwntools) (2.23.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from pwntools) (1.15.0)
# Requirement already satisfied: pyelftools>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from pwntools) (0.27)
# Requirement already satisfied: rpyc in /usr/local/lib/python3.7/dist-packages (from pwntools) (5.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from pwntools) (2.8.2)
# Requirement already satisfied: ropgadget>=5.3 in /usr/local/lib/python3.7/dist-packages (from pwntools) (6.6)
# Requirement already satisfied: psutil>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from pwntools) (5.4.8)
# Requirement already satisfied: paramiko>=1.15.2 in /usr/local/lib/python3.7/dist-packages (from pwntools) (2.8.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from pwntools) (2.4.0)
# Requirement already satisfied: capstone>=3.0.5rc2 in /usr/local/lib/python3.7/dist-packages (from pwntools) (4.0.2)
# Requirement already satisfied: mako>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pwntools) (1.1.5)
# Requirement already satisfied: pysocks in /usr/local/lib/python3.7/dist-packages (from pwntools) (1.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pwntools) (21.0)
# Requirement already satisfied: pip>=6.0.8 in /usr/local/lib/python3.7/dist-packages (from pwntools) (21.1.3)
# Requirement already satisfied: pyserial>=2.7 in /usr/local/lib/python3.7/dist-packages (from pwntools) (3.5)
# Requirement already satisfied: colored-traceback in /usr/local/lib/python3.7/dist-packages (from pwntools) (0.3.0)
# Requirement already satisfied: pygments>=2.0 in /usr/local/lib/python3.7/dist-packages (from pwntools) (2.6.1)
# Requirement already satisfied: intervaltree>=3.0 in /usr/local/lib/python3.7/dist-packages (from pwntools) (3.1.0)
# Requirement already satisfied: unicorn<1.0.2rc4,>=1.0.2rc1 in /usr/local/lib/python3.7/dist-packages (from pwntools) (1.0.2rc3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from mako>=1.0.0->pwntools) (2.0.1)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko>=1.15.2->pwntools) (35.0.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko>=1.15.2->pwntools) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko>=1.15.2->pwntools) (1.4.0)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=1.15.2->pwntools) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=1.15.2->pwntools) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pwntools) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pwntools) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pwntools) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pwntools) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pwntools) (2.4.7)
# Requirement already satisfied: plumbum in /usr/local/lib/python3.7/dist-packages (from rpyc->pwntools) (1.7.0)

# %%
#!/usr/bin/env python3
import sys
import base64
from Crypto.Util.number import *
# from pwn import *
# import this

if sys.version_info.major == 2:
    print("You are running Python 2, which is no longer supported. Please update to Python 3.")

def byte_xor(ba1, ba2):
    return bytes([_a ^ _b for _a, _b in zip(ba1, ba2)])



raw = bytes.fromhex("0e0b213f26041e480b26217f27342e175d0e070a3c5b103e2526217f27342e175d0e077e263451150104")
byte_length = len(raw)
print(byte_length)
key = bytes(("myXORkey"*(int(byte_length/8)))+"my","ascii")
print(byte_xor(raw,key))


print(raw)
# Out:
# 1512
